# %%
import pandas as pd
import numpy as np 


df_uber = pd.read_csv('restaurants.csv')

# %%
import json
data = []
with open('yelp_academic_dataset_business.json', 'r') as file:
    for line in file:
        data.append(json.loads(line))

df_yelp = pd.DataFrame(data)

# %%
df_yelp
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
df_uber
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 55222  55223        14                     Jason's Deli (901 Mckinney)    4.6
# 55223  55224        52                                 Luciano's Pizza    NaN
# 55224  55225        76                           TJ’s Eatery On Tha Go    NaN
# 55225  55226        70                       Trash Panda Drinking Club    NaN
# 55226  55227         3    La Casa del Taco (2008 S Wayside Dr ste 100)    NaN
#
# ...

# %%
merged_df = pd.merge(df_uber, df_yelp, left_on=['lat', 'lng'], right_on=['latitude', 'longitude'])

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [id, position, name_x, score, ratings, category, price_range, full_address, zip_code, lat, lng, business_id, name_y, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []
#
# [0 rows x 25 columns]

# %%
a = set(df_yelp['postal_code'].unique())

# %%
b = set(df_uber['zip_code'].unique())

# %%
intersection = a.intersection(b)

# %%
intersection
# Out:
# {'19104',
#  '20781',
#  '33756',
#  '63112',
#  '77077',
#  '78704',
#  '78752',
#  '98501',
#  '99207',
#  '99324'}

# %%
intersection.remove('05201')

# %%
df_uber[df_uber['zip_code'].isin(intersection)].sort_values('zip_code')
# Out:
#           id  position                                               name  \
# 52937  52938        43                     Royal Eggs. (2616 Blodgett St)
# 26859  26860       186                                             GOSHEN
# 29085  29086       249                          Cafe Azul Caracas De Ayer
# 6312    6313         1                             CVS (250 COURT STREET)
# 43983  43984        22  CVS (1513 SOUTH VALLEY MILLS DRIVE, CORNER OF ...
# ...      ...       ...                                                ...
# 10224  10225        24                  Subway (1700 Se Meadowbrook Blvd)
# 10227  10228         6          Panda Express (1721 Se Meadowbrook Blvd.)
# 10231  10232        13                       The Human Bean (Walla Walla)
# 10232  10233        10      Del Taco (1725 S.E. Meadowbrook Blvd. | 1019)
# 10242  10243         5           Subway (1605 Se Meadowbrook Blvd Ste 10)
#
#        score  ratings                                           category  \
# ...

# %%
df_yelp[df_yelp['postal_code'].isin(intersection)].sort_values('postal_code')
# Out:
#                    business_id                          name  \
# 144012  g0fYqQRRKmYIfChE4jMLsg             All Service Citgo
# 82      ppFCk9aQkM338Rgwpl2F5A                          Wawa
# 92020   E2pfdKBpou7ZdIBxyZo1PQ           Ted's Pizza Express
# 92095   NEa3QfKlbLI-BFh9_DCPzw            Chewy's Food Truck
# 92107   Pf8c5eSvvSKgjqB53y82Mw                US Post Office
# ...                        ...                           ...
# 22204   2F7SSas3Yo0vjwaE9yjyxg           All Tiana's Parties
# 95091   oTRrNy5VIaTw7MKEvxZl7A              Wildlife Wonders
# 57522   Hct7t6IMP5LohOhBxOIq5Q         Therapeutic Evolution
# 10948   kNK3tjrKa6e_Tf9c9WWehA                   Suave Nails
# 29606   qbh_Xg-wfgk_qINdyApMag  Valvoline Instant Oil Change
#
#                                address           city state postal_code  \
# 144012                  212 Lincoln St     Bennington    VT       05201
# 82                    3604 Chestnut St   Philadelphia    PA       19104
# ...

# %%
df_uber
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 55222  55223        14                     Jason's Deli (901 Mckinney)    4.6
# 55223  55224        52                                 Luciano's Pizza    NaN
# 55224  55225        76                           TJ’s Eatery On Tha Go    NaN
# 55225  55226        70                       Trash Panda Drinking Club    NaN
# 55226  55227         3    La Casa del Taco (2008 S Wayside Dr ste 100)    NaN
#
# ...

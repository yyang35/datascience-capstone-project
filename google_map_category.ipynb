# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('reviews.csv')

# %%
df['rating_category'].unique()
# Out:
# array(['taste', 'menu', 'outdoor_atmosphere', 'indoor_atmosphere'],
#       dtype=object)

# %%
data_1 = np.array(df[df['rating_category'] == 'taste']['rating'])
data_2 = np.array(df[df['rating_category'] ==  'menu']['rating'])
data_3 = np.array(df[df['rating_category'] == 'outdoor_atmosphere']['rating'])
data_4 = np.array(df[df['rating_category'] == 'indoor_atmosphere']['rating'])

data = [data_1, data_2, data_3, data_4]

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
 
# Creating dataset
np.random.seed(10)
 
data_1 = np.array(df[df['rating_category'] == 'taste']['rating'])
data_2 = np.array(df[df['rating_category'] ==  'menu']['rating'])
data_3 = np.array(df[df['rating_category'] == 'outdoor_atmosphere']['rating'])
data_4 = np.array(df[df['rating_category'] == 'indoor_atmosphere']['rating'])

data = [data_1, data_2, data_3, data_4]

 
fig = plt.figure(figsize =(10, 7))


ax = fig.add_axes([0, 0, 1, 1], facecolor= '#FDF7F4')


bp = ax.boxplot(data, vert = 0)


plt.xlabel('Sentiment')
plt.ylabel('Rating')
plt.grid(True, linestyle='--')
plt.sho

#plt.xlim()
plt.ylim(0,6)

# show plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> plt.ylabel('Rating')
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a> plt.grid(True, linestyle='--')
# ---> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a> plt.sho
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a> #plt.xlim()
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a> plt.ylim(0,6)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['A', 'B', 'C']
series_1 = [4, 2, 3]
series_2 = [3, 6, 5]
series_3 = [5, 1, 2]

barWidth = 0.25
r1 = np.arange(len(categories))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, series_1, color='blue', width=barWidth, edgecolor='grey', label='series 1')
plt.bar(r2, series_2, color='red', width=barWidth, edgecolor='grey', label='series 2')
plt.bar(r3, series_3, color='green', width=barWidth, edgecolor='grey', label='series 3')

plt.xlabel('categories', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(series_1))], categories)

plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data
data = [1, 1, 1, 2, 3, 3, 4, 4, 4, 4]

sns.stripplot(data_1, jitter=True)
plt.show()

# %%
def gaussian(x, A, mu, sigma):
    return A * np.exp(-(x - mu)**2 / (2 * sigma**2))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
data_1 = np.array(df[df['rating_category'] == 'taste']['rating'])
data_2 = np.array(df[df['rating_category'] ==  'menu']['rating'])
data_3 = np.array(df[df['rating_category'] == 'outdoor_atmosphere']['rating'])
data_4 = np.array(df[df['rating_category'] == 'indoor_atmosphere']['rating'])

data = [data_1, data_2, data_3, data_4]

# Loop through distance slices
for data_f in data:
    # Filter the DataFrame for the current distance range
    filtered_df = data_f.astype(str)
    
    # Count the number of restaurants for each star rating in the filtered DataFrame
    star_counts = filtered_df['rating'].value_counts().sort_index()
    
    params, covariance = curve_fit(gaussian, star_counts.index, star_counts.values)
    A_fit, mu_fit, sigma_fit = params

    x_fit = np.linspace(0, 6, 1000)
    y_fit = gaussian(x_fit, A_fit, mu_fit, sigma_fit)


    plt.figure(figsize=(8, 6))
    plt.bar(star_counts.index, star_counts.values, tick_label=star_counts.index, width=0.6, align='center')
    plt.plot(x_fit, y_fit, 'r-', label='Fitted Gaussian', linewidth=2)
    plt.xlim(0.5, 5.3)
    plt.xlabel('Star Rating')
    plt.ylabel('Number of Restaurants')
    #plt.title(f'Restaurant Star Ratings ({min_distance} to {max_distance} km)')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.text(0, 10, f'mu: {mu_fit:.2f}, sigma: {sigma_fit:.2f}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 9 line 1
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> filtered_df = data_f.astype(str)
#      <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> # Count the number of restaurants for each star rating in the filtered DataFrame
# ---> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> star_counts = filtered_df['rating'].value_counts().sort_index()
# ...

# %%
filtered_df['rating'].value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> filtered_df['rating'].value_counts().sort_index()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
filtered_df['rating']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> filtered_df['rating']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data_1['rating'].value_counts().reset_index()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> data_1['rating'].value_counts().reset_index()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
'taste', 'menu', 'outdoor_atmosphere', 'indoor_atmosphere'],
      dtype=object)

ti
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sherryyang/Projects/cse481/google_map_category.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/sherryyang/Projects/cse481/google_map_category.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> data_1.type()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
title = ['taste', 'menu', 'outdoor_atmosphere', 'indoor_atmosphere']

# %%
for i in range(len(data)):
    plt.hist(data[i], bins=range(1, 7), edgecolor='black')  # Assuming values are between 1 and 5
    plt.title(title[i])
    plt.xlabel('rating')
    plt.ylabel('Frequency')
    plt.show()
